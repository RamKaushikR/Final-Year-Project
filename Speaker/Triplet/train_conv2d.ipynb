# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir('/content/gdrive/My Drive/FYP/Speaker/Triplet')
os.environ['TF_CPP_MIN_LOG_LEVEL']= '3'

import tensorflow as tf
tf.autograph.set_verbosity(0)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from siamese import Siamese
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# %%
MODEL_PATH = 'Model/Conv2D/'
CORE_PATH = '../Classification/Model/Conv_2D/'
DATA_PATH = '../Data/Data/'

# %%
print('Loading data')
with open(DATA_PATH + 'train.pickle', 'rb') as f:
    X_train, s_train = pickle.load(f)
with open(DATA_PATH + 'val.pickle', 'rb') as f:
    X_val, s_val = pickle.load(f)
# Out:
# Loading data

# %%
def get_triplet(X, s):
    speakers = list(s.keys())
    num = len(speakers)
    
    s1 = np.random.randint(0, num)
    s2 = np.random.randint(0, num)
    while s1 == s2:
        s2 = np.random.randint(0, num)
    
    l1, h1 = s[speakers[s1]]
    l2, h2 = s[speakers[s2]]
    
    i1_1 = np.random.randint(l1, h1+1) - l1
    i1_2 = np.random.randint(l1, h1+1) - l1
    while i1_2 == i1_1:
        i1_2 = np.random.randint(l1, h1+1) - l1
    
    i2 = np.random.randint(l2, h2+1) - l2
    
    a = abs(X[s1][i1_1])
    p = abs(X[s1][i1_2])
    n = abs(X[s2][i2])
    
    return a.reshape(W, H, 1), p.reshape(W, H, 1), n.reshape(W, H, 1)

def get_batch(X, s, batch_size):
    anchor = []
    positive = []
    negative = []
    
    for _ in range(batch_size):
        a, p, n = get_triplet(X, s)
        anchor.append(a)
        positive.append(p)
        negative.append(n)
        
    anchor, positive, negative = np.array(anchor), np.array(positive), np.array(negative)
    _ = np.random.permutation(len(anchor))
    return [anchor[_], positive[_], negative[_]]

# %%
def train_generator(batch_size, encoding_dim):
    while True:
        X = get_batch(X_train, s_train, batch_size)
        y = np.zeros((batch_size, 3*encoding_dim))
        yield X, y
        
def val_generator(batch_size, encoding_dim):
    while True:
        X = get_batch(X_val, s_val, batch_size)
        y = np.zeros((batch_size, 3*encoding_dim))
        yield X, y

# %%
BATCH_SIZE = 256
MARGIN = 1
LR = 0.0006
W = 300
H = 128
EPOCHS = 50
STEPS_PER_EPOCH = 100
VALIDATION_STEPS = 50
ENCODING_DIM = 128

# %%
def train(model):
    filepath = MODEL_PATH + 'conv2d_{epoch:02d}.h5'
    checkpoint = ModelCheckpoint(filepath, save_weights_only=True, period=10)
    history = model.model.fit(train_generator(BATCH_SIZE, ENCODING_DIM), epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH, callbacks=[checkpoint],
                              validation_data=(val_generator(BATCH_SIZE, ENCODING_DIM)),
                              validation_steps=VALIDATION_STEPS, shuffle=True)
                              
    return history

# %%
print('Creating Model')
model = Siamese((W, H, 1), name='conv_2d', lr=LR, margin=MARGIN, core_path=CORE_PATH+'conv2d_20.h5')
model.model.summary()
# Out:
# Creating Model
# Model: "output"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          618312      input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           sequential[0][0]
#                                                                  sequential[1][0]
#                                                                  sequential[2][0]
# ==================================================================================================
# Total params: 618,312
# Trainable params: 618,312
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = train(model)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 100/100 [==============================] - 48s 389ms/step - loss: 0.9998 - val_loss: 0.4664
# Epoch 2/50
# 100/100 [==============================] - 39s 386ms/step - loss: 0.5199 - val_loss: 0.4377
# Epoch 3/50
# 100/100 [==============================] - 39s 390ms/step - loss: 0.4828 - val_loss: 0.4272
# Epoch 4/50
# 100/100 [==============================] - 40s 396ms/step - loss: 0.4678 - val_loss: 0.4232
# Epoch 5/50
# 100/100 [==============================] - 40s 400ms/step - loss: 0.4508 - val_loss: 0.4092
# Epoch 6/50
# 100/100 [==============================] - 40s 401ms/step - loss: 0.4461 - val_loss: 0.4155
# Epoch 7/50
# 100/100 [==============================] - 40s 403ms/step - loss: 0.4255 - val_loss: 0.4316
# Epoch 8/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.4139 - val_loss: 0.3849
# Epoch 9/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.4069 - val_loss: 0.4277
# Epoch 10/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3961 - val_loss: 0.3981
# Epoch 11/50
# 100/100 [==============================] - 41s 409ms/step - loss: 0.3708 - val_loss: 0.4016
# Epoch 12/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3878 - val_loss: 0.3859
# Epoch 13/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3662 - val_loss: 0.4177
# Epoch 14/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3554 - val_loss: 0.4001
# Epoch 15/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.3589 - val_loss: 0.3961
# Epoch 16/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.3598 - val_loss: 0.4186
# Epoch 17/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.3390 - val_loss: 0.4007
# Epoch 18/50
# 100/100 [==============================] - 41s 409ms/step - loss: 0.3355 - val_loss: 0.4296
# Epoch 19/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.3333 - val_loss: 0.4025
# Epoch 20/50
# 100/100 [==============================] - 41s 407ms/step - loss: 0.3244 - val_loss: 0.4208
# Epoch 21/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3294 - val_loss: 0.4002
# Epoch 22/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.3214 - val_loss: 0.4263
# Epoch 23/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3139 - val_loss: 0.4251
# Epoch 24/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3121 - val_loss: 0.4778
# Epoch 25/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3175 - val_loss: 0.4263
# Epoch 26/50
# 100/100 [==============================] - 41s 408ms/step - loss: 0.3089 - val_loss: 0.3755
# Epoch 27/50
# 100/100 [==============================] - 40s 404ms/step - loss: 0.3031 - val_loss: 0.3974
# Epoch 28/50
# 100/100 [==============================] - 40s 406ms/step - loss: 0.2911 - val_loss: 0.3915
# Epoch 29/50
# 100/100 [==============================] - 41s 410ms/step - loss: 0.2936 - val_loss: 0.3930
# Epoch 30/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.3011 - val_loss: 0.4631
# Epoch 31/50
# 100/100 [==============================] - 41s 407ms/step - loss: 0.2925 - val_loss: 0.4459
# Epoch 32/50
# 100/100 [==============================] - 41s 406ms/step - loss: 0.2812 - val_loss: 0.3830
# Epoch 33/50
# 100/100 [==============================] - 41s 407ms/step - loss: 0.2508 - val_loss: 0.3710
# Epoch 34/50
# 100/100 [==============================] - 41s 410ms/step - loss: 0.2300 - val_loss: 0.3355
# Epoch 35/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.2090 - val_loss: 0.3430
# Epoch 36/50
# 100/100 [==============================] - 41s 407ms/step - loss: 0.2046 - val_loss: 0.3299
# Epoch 37/50
# 100/100 [==============================] - 40s 402ms/step - loss: 0.1921 - val_loss: 0.3662
# Epoch 38/50
# 100/100 [==============================] - 40s 403ms/step - loss: 0.1857 - val_loss: 0.3571
# Epoch 39/50
# 100/100 [==============================] - 40s 405ms/step - loss: 0.1808 - val_loss: 0.3158
# Epoch 40/50
# 100/100 [==============================] - 40s 400ms/step - loss: 0.1801 - val_loss: 0.3367
# Epoch 41/50
# 100/100 [==============================] - 40s 402ms/step - loss: 0.1668 - val_loss: 0.3261
# Epoch 42/50
# 100/100 [==============================] - 40s 401ms/step - loss: 0.1714 - val_loss: 0.3385
# Epoch 43/50
# 100/100 [==============================] - 40s 402ms/step - loss: 0.1715 - val_loss: 0.3108
# Epoch 44/50
# 100/100 [==============================] - 40s 402ms/step - loss: 0.1666 - val_loss: 0.3332
# Epoch 45/50
# 100/100 [==============================] - 40s 400ms/step - loss: 0.1658 - val_loss: 0.3157
# Epoch 46/50
# 100/100 [==============================] - 40s 400ms/step - loss: 0.1586 - val_loss: 0.3208
# Epoch 47/50
# 100/100 [==============================] - 40s 401ms/step - loss: 0.1631 - val_loss: 0.3193
# Epoch 48/50
# 100/100 [==============================] - 40s 402ms/step - loss: 0.1485 - val_loss: 0.3127
# Epoch 49/50
# 100/100 [==============================] - 40s 400ms/step - loss: 0.1545 - val_loss: 0.2974
# Epoch 50/50
# 100/100 [==============================] - 40s 398ms/step - loss: 0.1634 - val_loss: 0.3118

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
with open(MODEL_PATH + 'conv2d_history.pickle', 'wb') as f:
    pickle.dump(history.history, f)
