# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/FYP/Speaker/Triplet')
os.environ['TF_CPP_MIN_LOG_LEVEL']= '3'

import tensorflow as tf
tf.autograph.set_verbosity(0)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from siamese import Siamese
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K

# %%
MODEL_PATH = 'Model/Conv1D/'
CORE_PATH = '../Classification/Model/Conv_1D/'
DATA_PATH = '../Data/Data/'

# %%
print('Loading data')
with open(DATA_PATH + 'train.pickle', 'rb') as f:
    X_train, s_train = pickle.load(f)
with open(DATA_PATH + 'val.pickle', 'rb') as f:
    X_val, s_val = pickle.load(f)
# Out:
# Loading data

# %%
def get_triplet(X, s):
    speakers = list(s.keys())
    num = len(speakers)
    
    s1 = np.random.randint(0, num)
    s2 = np.random.randint(0, num)
    while s1 == s2:
        s2 = np.random.randint(0, num)
    
    l1, h1 = s[speakers[s1]]
    l2, h2 = s[speakers[s2]]
    
    i1_1 = np.random.randint(l1, h1+1) - l1
    i1_2 = np.random.randint(l1, h1+1) - l1
    while i1_2 == i1_1:
        i1_2 = np.random.randint(l1, h1+1) - l1
    
    i2 = np.random.randint(l2, h2+1) - l2
    
    a = abs(X[s1][i1_1])
    p = abs(X[s1][i1_2])
    n = abs(X[s2][i2])
    
    return a.reshape(W, H, 1), p.reshape(W, H, 1), n.reshape(W, H, 1)

def get_batch(X, s, batch_size):
    anchor = []
    positive = []
    negative = []
    
    for _ in range(batch_size):
        a, p, n = get_triplet(X, s)
        anchor.append(a)
        positive.append(p)
        negative.append(n)
        
    anchor, positive, negative = np.array(anchor), np.array(positive), np.array(negative)
    _ = np.random.permutation(len(anchor))
    return [anchor[_], positive[_], negative[_]]

# %%
def train_generator(batch_size, encoding_dim):
    while True:
        X = get_batch(X_train, s_train, batch_size)
        y = np.zeros((batch_size, 3*encoding_dim))
        yield X, y
        
def val_generator(batch_size, encoding_dim):
    while True:
        X = get_batch(X_val, s_val, batch_size)
        y = np.zeros((batch_size, 3*encoding_dim))
        yield X, y

# %%
BATCH_SIZE = 256
MARGIN = 1
LR = 0.0006
W = 300
H = 128
EPOCHS = 50
STEPS_PER_EPOCH = 100
VALIDATION_STEPS = 50
ENCODING_DIM = 128

# %%
def train(model):
    filepath = MODEL_PATH + 'conv1d_{epoch:02d}.h5'
    checkpoint = ModelCheckpoint(filepath, save_weights_only=True, period=10)
    history = model.model.fit(train_generator(BATCH_SIZE, ENCODING_DIM), epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH, callbacks=[checkpoint],
                              validation_data=(val_generator(BATCH_SIZE, ENCODING_DIM)),
                              validation_steps=VALIDATION_STEPS, shuffle=True)
                              
    return history

# %%
print('Creating Model')
model = Siamese((W, H, 1), name='conv_1d', lr=LR, margin=MARGIN, core_path=CORE_PATH+'conv1d_20.h5')
model.model.summary()
# Out:
# Creating Model
# Model: "output"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          150872      input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           sequential[0][0]
#                                                                  sequential[1][0]
#                                                                  sequential[2][0]
# ==================================================================================================
# Total params: 150,872
# Trainable params: 150,872
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = train(model)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 100/100 [==============================] - 308s 3s/step - loss: 1.2610 - val_loss: 0.4720
# Epoch 2/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.4565 - val_loss: 0.4159
# Epoch 3/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.4066 - val_loss: 0.4240
# Epoch 4/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.3602 - val_loss: 0.4152
# Epoch 5/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.3467 - val_loss: 0.4358
# Epoch 6/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.3214 - val_loss: 0.4038
# Epoch 7/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.3173 - val_loss: 0.4307
# Epoch 8/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2996 - val_loss: 0.4191
# Epoch 9/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2875 - val_loss: 0.4344
# Epoch 10/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2878 - val_loss: 0.4117
# Epoch 11/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2735 - val_loss: 0.3954
# Epoch 12/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2709 - val_loss: 0.4251
# Epoch 13/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2722 - val_loss: 0.4008
# Epoch 14/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2646 - val_loss: 0.4027
# Epoch 15/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2603 - val_loss: 0.4220
# Epoch 16/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2590 - val_loss: 0.3950
# Epoch 17/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2497 - val_loss: 0.3866
# Epoch 18/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2516 - val_loss: 0.3864
# Epoch 19/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2419 - val_loss: 0.4272
# Epoch 20/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2398 - val_loss: 0.3824
# Epoch 21/50
# 100/100 [==============================] - 296s 3s/step - loss: 0.2439 - val_loss: 0.3992
# Epoch 22/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2458 - val_loss: 0.4175
# Epoch 23/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2316 - val_loss: 0.4127
# Epoch 24/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2441 - val_loss: 0.4074
# Epoch 25/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2345 - val_loss: 0.4282
# Epoch 26/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2389 - val_loss: 0.3798
# Epoch 27/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2240 - val_loss: 0.3863
# Epoch 28/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2227 - val_loss: 0.4230
# Epoch 29/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2211 - val_loss: 0.3940
# Epoch 30/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2146 - val_loss: 0.4031
# Epoch 31/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2182 - val_loss: 0.4167
# Epoch 32/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2187 - val_loss: 0.3815
# Epoch 33/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2170 - val_loss: 0.3847
# Epoch 34/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2011 - val_loss: 0.3867
# Epoch 35/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2075 - val_loss: 0.4027
# Epoch 36/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2113 - val_loss: 0.3912
# Epoch 37/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2004 - val_loss: 0.3998
# Epoch 38/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2086 - val_loss: 0.3824
# Epoch 39/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1985 - val_loss: 0.3756
# Epoch 40/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.2002 - val_loss: 0.3724
# Epoch 41/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1895 - val_loss: 0.3710
# Epoch 42/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1913 - val_loss: 0.3959
# Epoch 43/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1852 - val_loss: 0.3887
# Epoch 44/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1831 - val_loss: 0.3733
# Epoch 45/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1881 - val_loss: 0.3951
# Epoch 46/50
# 100/100 [==============================] - 296s 3s/step - loss: 0.1867 - val_loss: 0.3903
# Epoch 47/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1914 - val_loss: 0.4022
# Epoch 48/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1895 - val_loss: 0.3709
# Epoch 49/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1774 - val_loss: 0.3962
# Epoch 50/50
# 100/100 [==============================] - 297s 3s/step - loss: 0.1806 - val_loss: 0.3962

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
with open(MODEL_PATH + 'conv1d_history.pickle', 'wb') as f:
    pickle.dump(history.history, f)
