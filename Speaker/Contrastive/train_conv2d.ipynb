# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/FYP/Speaker/Contrastive')
os.environ['TF_CPP_MIN_LOG_LEVEL']= '3'

import tensorflow as tf
tf.autograph.set_verbosity(0)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from siamese import Siamese
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
MODEL_PATH = 'Model/Conv2D/'
CORE_PATH = '../Classification/Model/Conv_2D/'
DATA_PATH = '../Data/Data/'

# %%
def get_pairs(X, s, sim):
    speakers = list(s.keys())
    num = len(speakers)
    
    if sim:
        s1 = np.random.randint(0, num)
        l1, h1 = s[speakers[s1]]
        
        i1_1 = np.random.randint(l1, h1+1) - l1
        i1_2 = np.random.randint(l1, h1+1) - l1
        while i1_2 == i1_1:
            i1_2 = np.random.randint(l1, h1+1) - l1
            
        p1 = abs(X[s1][i1_1])
        p2 = abs(X[s1][i1_2])
        y = 0.
        
    else:
        s1 = np.random.randint(0, num)
        s2 = np.random.randint(0, num)
        while s1 == s2:
            s2 = np.random.randint(0, num)
            
        l1, h1 = s[speakers[s1]]
        l2, h2 = s[speakers[s2]]
        
        i1 = np.random.randint(l1, h1+1) - l1
        i2 = np.random.randint(l2, h2+1) - l2
        
        p1 = abs(X[s1][i1])
        p2 = abs(X[s2][i2])
        y = 1.
    
    return p1.reshape(W, H, 1), p2.reshape(W, H, 1), y

def get_batch(X, s, batch_size):
    pair1 = []
    pair2 = []
    labels = []
    
    for _ in range(batch_size // 2):
        p1, p2, y = get_pairs(X, s, True)
        pair1.append(p1)
        pair2.append(p2)
        labels.append(y)
        
    for _ in range(batch_size // 2):
        p1, p2, y = get_pairs(X, s, False)
        pair1.append(p1)
        pair2.append(p2)
        labels.append(y)
        
    pair1, pair2, labels = np.array(pair1), np.array(pair2), np.array(labels)
    _ = np.random.permutation(len(pair1))
    return [pair1[_], pair2[_]], labels[_]

# %%
def train_generator(batch_size):
    while True:
        X, y = get_batch(X_train, s_train, batch_size)
        yield X, y
        
def val_generator(batch_size):
    while True:
        X, y = get_batch(X_val, s_val, batch_size)
        yield X, y

# %%
BATCH_SIZE = 128
MARGIN = 0.5
LR = 0.0006
W = 300
H = 128
EPOCHS = 50
STEPS_PER_EPOCH = 100
VALIDATION_STEPS = 50

# %%
def train(model):
    filepath = MODEL_PATH + 'conv2d_{epoch:02d}.h5'
    checkpoint = ModelCheckpoint(filepath, save_weights_only=True, period=10)
    history = model.model.fit(train_generator(BATCH_SIZE), epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH, callbacks=[checkpoint],
                              validation_data=(val_generator(BATCH_SIZE)),
                              validation_steps=VALIDATION_STEPS, shuffle=True)
                              
    return history

# %%
print('Creating Model')
model = Siamese((W, H, 1), name='conv_2d', lr=LR, margin=MARGIN, core_path=CORE_PATH+'conv2d_20.h5')
model.model.summary()
# Out:
# Creating Model
# Model: "conv_2d"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          618312      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           sequential[0][0]
#                                                                  sequential[1][0]
# ==================================================================================================
# Total params: 618,312
# Trainable params: 618,312
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print('Loading data')
with open(DATA_PATH + 'train.pickle', 'rb') as f:
    X_train, s_train = pickle.load(f)
with open(DATA_PATH + 'val.pickle', 'rb') as f:
    X_val, s_val = pickle.load(f)
# Out:
# Loading data

# %%
history = train(model)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 100/100 [==============================] - 25s 133ms/step - loss: 0.3055 - val_loss: 0.0512
# Epoch 2/50
# 100/100 [==============================] - 13s 127ms/step - loss: 0.0538 - val_loss: 0.0433
# Epoch 3/50
# 100/100 [==============================] - 13s 128ms/step - loss: 0.0484 - val_loss: 0.0441
# Epoch 4/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0483 - val_loss: 0.0400
# Epoch 5/50
# 100/100 [==============================] - 13s 128ms/step - loss: 0.0438 - val_loss: 0.0381
# Epoch 6/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0445 - val_loss: 0.0383
# Epoch 7/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0426 - val_loss: 0.0375
# Epoch 8/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0421 - val_loss: 0.0365
# Epoch 9/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0392 - val_loss: 0.0363
# Epoch 10/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0385 - val_loss: 0.0383
# Epoch 11/50
# 100/100 [==============================] - 13s 132ms/step - loss: 0.0374 - val_loss: 0.0364
# Epoch 12/50
# 100/100 [==============================] - 13s 132ms/step - loss: 0.0356 - val_loss: 0.0361
# Epoch 13/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0350 - val_loss: 0.0366
# Epoch 14/50
# 100/100 [==============================] - 13s 132ms/step - loss: 0.0342 - val_loss: 0.0361
# Epoch 15/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0338 - val_loss: 0.0358
# Epoch 16/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0314 - val_loss: 0.0362
# Epoch 17/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0317 - val_loss: 0.0347
# Epoch 18/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0309 - val_loss: 0.0350
# Epoch 19/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0310 - val_loss: 0.0359
# Epoch 20/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0304 - val_loss: 0.0362
# Epoch 21/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0299 - val_loss: 0.0363
# Epoch 22/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0297 - val_loss: 0.0363
# Epoch 23/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0291 - val_loss: 0.0359
# Epoch 24/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0278 - val_loss: 0.0375
# Epoch 25/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0286 - val_loss: 0.0364
# Epoch 26/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0283 - val_loss: 0.0357
# Epoch 27/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0278 - val_loss: 0.0365
# Epoch 28/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0280 - val_loss: 0.0345
# Epoch 29/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0268 - val_loss: 0.0350
# Epoch 30/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0271 - val_loss: 0.0354
# Epoch 31/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0272 - val_loss: 0.0349
# Epoch 32/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0266 - val_loss: 0.0353
# Epoch 33/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0267 - val_loss: 0.0359
# Epoch 34/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0255 - val_loss: 0.0361
# Epoch 35/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0248 - val_loss: 0.0363
# Epoch 36/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0260 - val_loss: 0.0381
# Epoch 37/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0253 - val_loss: 0.0347
# Epoch 38/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0245 - val_loss: 0.0376
# Epoch 39/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.0250 - val_loss: 0.0362
# Epoch 40/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0242 - val_loss: 0.0351
# Epoch 41/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0235 - val_loss: 0.0366
# Epoch 42/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0238 - val_loss: 0.0360
# Epoch 43/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0239 - val_loss: 0.0354
# Epoch 44/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0234 - val_loss: 0.0361
# Epoch 45/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0233 - val_loss: 0.0345
# Epoch 46/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0238 - val_loss: 0.0388
# Epoch 47/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0233 - val_loss: 0.0370
# Epoch 48/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0227 - val_loss: 0.0368
# Epoch 49/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.0228 - val_loss: 0.0367
# Epoch 50/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.0226 - val_loss: 0.0375

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Conv2D Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
with open(MODEL_PATH + 'conv2d_history.pickle', 'wb') as f:
    pickle.dump(history.history, f)
