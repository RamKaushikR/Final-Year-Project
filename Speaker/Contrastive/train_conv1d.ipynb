# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/My Drive/FYP/Speaker/Contrastive')
os.environ['TF_CPP_MIN_LOG_LEVEL']= '3'

import tensorflow as tf
tf.autograph.set_verbosity(0)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from siamese import Siamese
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
MODEL_PATH = 'Model/Conv1D/'
CORE_PATH = '../Classification/Model/Conv_1D/'
DATA_PATH = '../Data/Data/'

# %%
print('Loading data')
with open(DATA_PATH + 'train.pickle', 'rb') as f:
    X_train, s_train = pickle.load(f)
with open(DATA_PATH + 'val.pickle', 'rb') as f:
    X_val, s_val = pickle.load(f)
# Out:
# Loading data

# %%
def get_pairs(X, s, sim):
    speakers = list(s.keys())
    num = len(speakers)
    
    if sim:
        s1 = np.random.randint(0, num)
        l1, h1 = s[speakers[s1]]
        
        i1_1 = np.random.randint(l1, h1+1) - l1
        i1_2 = np.random.randint(l1, h1+1) - l1
        while i1_2 == i1_1:
            i1_2 = np.random.randint(l1, h1+1) - l1
            
        p1 = abs(X[s1][i1_1])
        p2 = abs(X[s1][i1_2])
        y = 0.
        
    else:
        s1 = np.random.randint(0, num)
        s2 = np.random.randint(0, num)
        while s1 == s2:
            s2 = np.random.randint(0, num)
            
        l1, h1 = s[speakers[s1]]
        l2, h2 = s[speakers[s2]]
        
        i1 = np.random.randint(l1, h1+1) - l1
        i2 = np.random.randint(l2, h2+1) - l2
        
        p1 = abs(X[s1][i1])
        p2 = abs(X[s2][i2])
        y = 1.
    
    return p1.reshape(W, H, 1), p2.reshape(W, H, 1), y

def get_batch(X, s, batch_size):
    pair1 = []
    pair2 = []
    labels = []
    
    for _ in range(batch_size // 2):
        p1, p2, y = get_pairs(X, s, True)
        pair1.append(p1)
        pair2.append(p2)
        labels.append(y)
        
    for _ in range(batch_size // 2):
        p1, p2, y = get_pairs(X, s, False)
        pair1.append(p1)
        pair2.append(p2)
        labels.append(y)
        
    pair1, pair2, labels = np.array(pair1), np.array(pair2), np.array(labels)
    _ = np.random.permutation(len(pair1))
    return [pair1[_], pair2[_]], labels[_]

# %%
def train_generator(batch_size):
    while True:
        X, y = get_batch(X_train, s_train, batch_size)
        yield X, y
        
def val_generator(batch_size):
    while True:
        X, y = get_batch(X_val, s_val, batch_size)
        yield X, y

# %%
BATCH_SIZE = 256
MARGIN = 0.5
LR = 0.0006
W = 300
H = 128
EPOCHS = 50
STEPS_PER_EPOCH = 100
VALIDATION_STEPS = 50

# %%
def train(model):
    filepath = MODEL_PATH + 'conv1d_{epoch:02d}.h5'
    checkpoint = ModelCheckpoint(filepath, save_weights_only=True, period=10)
    history = model.model.fit(train_generator(BATCH_SIZE), epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH, callbacks=[checkpoint],
                              validation_data=(val_generator(BATCH_SIZE)),
                              validation_steps=VALIDATION_STEPS, shuffle=True)
                              
    return history

# %%
print('Creating Model')
model = Siamese((W, H, 1), name='conv_1d', lr=LR, margin=MARGIN, core_path=CORE_PATH+'conv1d_20.h5')
model.model.summary()
# Out:
# Creating Model
# Model: "conv_1d"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 300, 128, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          150872      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           sequential[0][0]
#                                                                  sequential[1][0]
# ==================================================================================================
# Total params: 150,872
# Trainable params: 150,872
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = train(model)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 100/100 [==============================] - 208s 2s/step - loss: 0.0985 - val_loss: 0.0440
# Epoch 2/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0452 - val_loss: 0.0382
# Epoch 3/50
# 100/100 [==============================] - 199s 2s/step - loss: 0.0403 - val_loss: 0.0393
# Epoch 4/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0363 - val_loss: 0.0380
# Epoch 5/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0353 - val_loss: 0.0369
# Epoch 6/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0332 - val_loss: 0.0372
# Epoch 7/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0319 - val_loss: 0.0412
# Epoch 8/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0301 - val_loss: 0.0373
# Epoch 9/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0290 - val_loss: 0.0396
# Epoch 10/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0293 - val_loss: 0.0382
# Epoch 11/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0285 - val_loss: 0.0387
# Epoch 12/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0277 - val_loss: 0.0389
# Epoch 13/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0272 - val_loss: 0.0373
# Epoch 14/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0278 - val_loss: 0.0376
# Epoch 15/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0265 - val_loss: 0.0380
# Epoch 16/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0265 - val_loss: 0.0363
# Epoch 17/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0259 - val_loss: 0.0361
# Epoch 18/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0258 - val_loss: 0.0364
# Epoch 19/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0250 - val_loss: 0.0372
# Epoch 20/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0249 - val_loss: 0.0383
# Epoch 21/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0240 - val_loss: 0.0374
# Epoch 22/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0247 - val_loss: 0.0362
# Epoch 23/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0241 - val_loss: 0.0364
# Epoch 24/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0230 - val_loss: 0.0377
# Epoch 25/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0232 - val_loss: 0.0364
# Epoch 26/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0225 - val_loss: 0.0382
# Epoch 27/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0225 - val_loss: 0.0386
# Epoch 28/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0225 - val_loss: 0.0370
# Epoch 29/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0227 - val_loss: 0.0367
# Epoch 30/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0219 - val_loss: 0.0369
# Epoch 31/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0218 - val_loss: 0.0377
# Epoch 32/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0216 - val_loss: 0.0377
# Epoch 33/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0216 - val_loss: 0.0374
# Epoch 34/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0213 - val_loss: 0.0369
# Epoch 35/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0210 - val_loss: 0.0374
# Epoch 36/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0209 - val_loss: 0.0369
# Epoch 37/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0199 - val_loss: 0.0404
# Epoch 38/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0204 - val_loss: 0.0392
# Epoch 39/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0198 - val_loss: 0.0380
# Epoch 40/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0197 - val_loss: 0.0380
# Epoch 41/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0199 - val_loss: 0.0377
# Epoch 42/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0194 - val_loss: 0.0382
# Epoch 43/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0189 - val_loss: 0.0382
# Epoch 44/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0194 - val_loss: 0.0372
# Epoch 45/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0194 - val_loss: 0.0392
# Epoch 46/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0184 - val_loss: 0.0388
# Epoch 47/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0186 - val_loss: 0.0389
# Epoch 48/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0189 - val_loss: 0.0376
# Epoch 49/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0183 - val_loss: 0.0409
# Epoch 50/50
# 100/100 [==============================] - 198s 2s/step - loss: 0.0186 - val_loss: 0.0388

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Conv1D Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
with open(MODEL_PATH + 'conv1d_history.pickle', 'wb') as f:
    pickle.dump(history.history, f)
